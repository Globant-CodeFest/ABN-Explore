# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 200)

# Define column names
col_names = ['ID', "LATITUDE", "LONGITUDE", "ELEVATION", "STATION"]
# Define value and flag names for each month

# Define column widths
col_widths = [12, 8, 10, 8, 25]

# Read the file
df = pd.read_fwf('EXPLOREDATA/ghcnm.tavg.v4.0.1.20230609.qfe.inv', widths=col_widths, names=col_names)

# %%
df.head()
# Out:
#             ID  LATITUDE  LONGITUDE  ELEVATION               STATION
# 0  ACW00011604   57.7667    11.8667       18.0                  SAVE
# 1  AE000041196   25.3330    55.5170       34.0    SHARJAH_INTER_AIRP
# 2  AEM00041184   25.6170    55.9330       31.0   RAS_AL_KHAIMAH_INTE
# 3  AEM00041194   25.2550    55.3640       10.4            DUBAI_INTL
# 4  AEM00041216   24.4300    54.4700        3.0  ABU_DHABI_BATEEN_AIR

# %%
# Create new column for country code
df["Country Code"] = df["ID"].str[:2]

# %%
df.head()
# Out:
#             ID  LATITUDE  LONGITUDE  ELEVATION               STATION  \
# 0  ACW00011604   57.7667    11.8667       18.0                  SAVE
# 1  AE000041196   25.3330    55.5170       34.0    SHARJAH_INTER_AIRP
# 2  AEM00041184   25.6170    55.9330       31.0   RAS_AL_KHAIMAH_INTE
# 3  AEM00041194   25.2550    55.3640       10.4            DUBAI_INTL
# 4  AEM00041216   24.4300    54.4700        3.0  ABU_DHABI_BATEEN_AIR
#
#   Country Code
# 0           AC
# 1           AE
# 2           AE
# 3           AE
# 4           AE

# %%
countryCodes = pd.read_csv('COUNTRYDATA/COUNTRIES.csv')
countryCodes.head()
# Out:
#   Country Code               Country
# 0           AA                 Aruba
# 1           AC   Antigua and Barbuda
# 2           AE  United Arab Emirates
# 3           AF           Afghanistan
# 4           AG               Algeria

# %%
# Merge the dataframes and drop the ID column
df = pd.merge(df, countryCodes, on='Country Code').drop('Country Code', axis=1)

# %%
df.head()
# Out:
#               STATION           ID             Country_x  LATITUDE  LONGITUDE  \
# 0                SAVE  ACW00011604   Antigua and Barbuda   57.7667    11.8667
# 1                SAVE  ACW00011604   Antigua and Barbuda   57.7667    11.8667
# 2                SAVE  ACW00011604   Antigua and Barbuda   57.7667    11.8667
# 3                SAVE  ACW00011604   Antigua and Barbuda   57.7667    11.8667
# 4  SHARJAH_INTER_AIRP  AE000041196  United Arab Emirates   25.3330    55.5170
#
#    ELEVATION             Country_y
# 0       18.0   Antigua and Barbuda
# 1       18.0   Antigua and Barbuda
# 2       18.0   Antigua and Barbuda
# 3       18.0   Antigua and Barbuda
# 4       34.0  United Arab Emirates

# %%
# Reorder columns
# STATION ID COUNTRY CODE COUNTRY LATITUDE LONGITUDE ELEVATION
df = df[['STATION', 'ID', 'Country', 'LATITUDE', 'LONGITUDE', 'ELEVATION']]

# %%
df.head()
# Out:
#                STATION           ID               Country  LATITUDE  \
# 0                 SAVE  ACW00011604   Antigua and Barbuda   57.7667
# 1                 SAVE  ACW00011604   Antigua and Barbuda   57.7667
# 2   SHARJAH_INTER_AIRP  AE000041196  United Arab Emirates   25.3330
# 3   SHARJAH_INTER_AIRP  AE000041196  United Arab Emirates   25.3330
# 4  RAS_AL_KHAIMAH_INTE  AEM00041184  United Arab Emirates   25.6170
#
#    LONGITUDE  ELEVATION
# 0    11.8667       18.0
# 1    11.8667       18.0
# 2    55.5170       34.0
# 3    55.5170       34.0
# 4    55.9330       31.0

# %%
# SAVE THE DATAFRAME BY SEPARATING THE DATA BY COUNTRY
for country in df['Country'].unique():
    df[df['Country'] == country].to_csv(f'STATION/{country}.csv', index=False)
